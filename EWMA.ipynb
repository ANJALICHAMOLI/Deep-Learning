# %% [markdown]
# <a href="https://colab.research.google.com/github/ANJALICHAMOLI/Deep-Learning/blob/main/EWMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d079df18-1df0-4711-9afc-a6ae8564b169" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d079df18-1df0-4711-9afc-a6ae8564b169">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'DailyDelhiClimate_data.numbers',
#  'DailyDelhiClimateTrain.csv',
#  'DailyDelhiClimateTest.csv',
#  'DailyDelhiClimate_data.csv',
#  'DailyDelhiClimate_data_nn.csv',
#  'sample_data']

# %%
df = pd.read_csv("DailyDelhiClimateTest.csv")

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df=df.iloc[1:115,0:2] #for 114 rows

# %%
df.head()
# Out:
#          date  meantemp
# 1  2013-01-02  7.400000
# 2  2013-01-03  7.166667
# 3  2013-01-04  8.666667
# 4  2013-01-05  6.000000
# 5  2013-01-06  7.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 3 to 115
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      113 non-null    object
#  1   meantemp  113 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ KB

# %%
plt.scatter(df['date'], df['meantemp'], color='red')

# %%
x1=df['meantemp'].ewm(alpha=0.1).mean()

# %%
x1
# Out:
# 1       7.400000
# 2       7.187879
# 3       8.520120
# 4       6.251785
# 5       6.925185
#          ...
# 110    27.941024
# 111    27.431602
# 112    28.505660
# 113    30.107709
# 114    31.039342
# Name: meantemp, Length: 114, dtype: float64

# %%
df['ewma']=x1
df
# Out:
#            date   meantemp       ewma
# 1    2013-01-02   7.400000   7.400000
# 2    2013-01-03   7.166667   7.187879
# 3    2013-01-04   8.666667   8.520120
# 4    2013-01-05   6.000000   6.251785
# 5    2013-01-06   7.000000   6.925185
# ..          ...        ...        ...
# 110  2013-04-21  27.666667  27.941024
# 111  2013-04-22  27.375000  27.431602
# 112  2013-04-23  28.625000  28.505660
# 113  2013-04-24  30.285714  30.107709
# 114  2013-04-25  31.142857  31.039342
#
# [114 rows x 3 columns]

# %%
plt.scatter(df['date'], df['ewma'], color='red')
plt.plot(df['date'],x1,color='black',label='alpha=0.1')
plt.legend()
plt.show()
